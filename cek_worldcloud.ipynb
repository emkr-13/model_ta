# %%
import pandas as pd

# %%
df = pd.read_csv('online_news_45000_clean_label_all_baru.csv')
df.head(10)
# Out:
#                                                title  \
# 0   Survei: PPP, Perindo, dan PSI Tak Lolos Parlemen
# 1  Megawati: Membangun Indonesia Tak Bisa Hanya d...
# 2  KPK Soal MA Cabut Aturan Koruptor Nyaleg: Biar...
# 3  Indikator: Ganjar dan Erick Thohir Capres-Cawa...
# 4  Hasto Respons Usulan Guntur Sukarno Sebut Joko...
# 5  Kemendikbudristek Respons Anggapan Literasi Wa...
# 6  Pertamina Gandeng LKPP Implementasikan Aplikas...
# 7  Heran Ada Isu Prabowo Duet dengan Ganjar, Mega...
# 8  Perempuan di Surabaya Ditipu Suami Ternyata Wa...
# 9  Hasil Rakernas, PDI-P Serahkan Pengumuman Cawa...
#
#                                              content tanggal_berita  \
# 0  Hasil survei Indikator Politik Indonesia menya...     2023-10-01
# 1  Ketua Umum PDIP, Megawati Soekarnoputri menyeb...     2023-10-01
# 2  Komisi Pemberantasan Korupsi (KPK) mengapresia...     2023-10-01
# 3  Hasil survei Indikator Politik Indonesia menun...     2023-10-01
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import time
sentiments = df['sentimen'].unique()

for sentiment in sentiments:
    text = " ".join(content for content in df[df['sentimen'] == sentiment]['content_clean'])
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
    
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title(f'Word Cloud for {sentiment.capitalize()} Sentiment')
    plt.show()
    
    time.sleep(2)  # Pause for 2 seconds before showing the next word cloud
