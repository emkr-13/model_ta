# %% [markdown]
# ### Model LDA dan LSA Pemilu

# %%
import pandas as pd

# %%
data=pd.read_csv('filtered_online_news_pemilu2.csv')
data.head(5)
# Out:
#                                                title  \
# 0  PAN x JakCloth! Pesta Anak Nongkrong Sambangi ...
# 1  Kapolri Bicara Arti Sumpah Pemuda di #DemiIndo...
# 2  Arahan Megawati di Rakernas IV PDIP: Turun ke ...
# 3  Bertemu Habib Rizieq, Cak Imin Bantah Bahas Du...
# 4  Menag Singgung Politisasi Agama di Pilgub DKI,...
#
#                                              content tanggal_berita  \
# 0  Kumaha barudak? Well!Yuk ramaikan Pesta Anak N...     10-11-2023
# 1  Kapolri Jenderal Lisyto Sigit Prabowo bicara a...     27-10-2023
# 2  Ketua Umum PDIP, Megawati Soekarnoputri mengin...     01-10-2023
# 3  Pasangan capres-cawapres dari Koalisi Perubaha...     01-10-2023
# 4  Ketum PKB Muhaimin Iskandar atau Cak Imin mere...     01-10-2023
#
#                                        content_clean  \
# 0  kumaha barudak well yuk ramaikan pesta anak no...
# 1  kapolri jenderal lisyto sigit prabowo bicara s...
# 2  ketua umum pdip megawati soekarnoputri kader m...
# 3  pasangan capres cawapres koalisi perubahan ani...
# 4  ketum pkb muhaimin iskandar cak imin merespons...
#
#                                          link_berita asal_berita sentimen
# 0  https://20.detik.com/advertorial/20231109-2311...  Detik News   netral
# 1  https://20.detik.com/demi-indonesia/20231027-2...  Detik News  positif
# 2  https://20.detik.com/detikupdate/20231001-2310...  Detik News   netral
# 3  https://20.detik.com/detikupdate/20231001-2310...  Detik News   netral
# 4  https://20.detik.com/detikupdate/20231001-2310...  Detik News   netral

# %%
len(data)
# Out:
# 28485

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Concatenate all texts into one string
all_texts = ' '.join(data['content_clean'])

# Generate a word cloud image
wordcloud = WordCloud(width=800, height=400, background_color ='white').generate(all_texts)

# Display the generated image:
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ## LDA

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# Membuat objek TfidfVectorizer
vectorizer = TfidfVectorizer(min_df=1,
                             norm='l2',
                             smooth_idf=True,
                             use_idf=True,
                             ngram_range=(1,2))

# %%
# Mengubah teks menjadi representasi vektor
X = vectorizer.fit_transform(data['content_clean'])

# Membuat model LDA dengan 10 topik
num_topics = 10
lda_model = LatentDirichletAllocation(n_components=num_topics, random_state=42)

# %%
# Melatih model LDA
lda_model.fit(X)

# Mendapatkan kata-kata kunci untuk setiap topik
feature_names = vectorizer.get_feature_names_out()

top_n_words = 5  # Jumlah kata kunci untuk setiap topik
for topic_idx, topic in enumerate(lda_model.components_):
    print(f"Topik {topic_idx + 1}:")
    print([feature_names[i] for i in topic.argsort()[:-top_n_words - 1:-1]])
# Out:
# Topik 1:
# ['doni', 'monardo', 'doni monardo', 'angket', 'hak angket']
# Topik 2:
# ['prabowo', 'gibran', 'ganjar', 'presiden', 'anies']
# Topik 3:
# ['kebakaran', 'tpa', 'tpa rawa', 'rawa kucing', 'rawa']
# Topik 4:
# ['masiku', 'harun masiku', 'harun', 'wahyu', 'wahyu setiawan']
# Topik 5:
# ['ppatk', 'transaksi', 'ivan', 'mencurigakan', 'transaksi janggal']
# Topik 6:
# ['cfd', 'perangkat desa', 'bawaslu dki', 'bawaslu jakarta', 'kabel']
# Topik 7:
# ['lukas', 'enembe', 'lukas enembe', 'antimafia', 'antimafia bola']
# Topik 8:
# ['kpk', 'firli', 'tersangka', 'syahrul', 'metro']
# Topik 9:
# ['soedirman', 'soedirman awards', 'lutfi', 'cacar', 'cacar monyet']
# Topik 10:
# ['roy suryo', 'suryo', 'roy', 'mikrofon', 'tawuran']

# %% [markdown]
# #### Visualasi

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import seaborn as sns
from sklearn.manifold import MDS

# %%
# Word Cloud
plt.figure(figsize=(12, 8))
for i in range(num_topics):
    plt.subplot(2, 5, i+1)
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(dict(zip(feature_names, lda_model.components_[i])))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(f'Topik {i+1}')
    plt.axis('off')
plt.tight_layout()
plt.show()

# %%
# Bar Plot
plt.figure(figsize=(12, 8))
for i in range(num_topics):
    plt.subplot(2, 5, i+1)
    sns.barplot(x=[feature_names[j] for j in lda_model.components_[i].argsort()[-top_n_words:]], y=lda_model.components_[i][lda_model.components_[i].argsort()[-top_n_words:]])
    plt.title(f'Topik {i+1}')
    plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## LSA

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

# Membuat vektor TF-IDF
vectorizer = TfidfVectorizer(min_df=1,
                             norm='l2',
                             smooth_idf=True,
                             use_idf=True,
                             ngram_range=(1,2))
X = vectorizer.fit_transform(data['content_clean'])

# Membuat model LSA dengan 10 topik
lsa_model = TruncatedSVD(n_components=10)
lsa_topic_matrix = lsa_model.fit_transform(X)

# Menampilkan kata-kata teratas untuk setiap topik
terms = vectorizer.get_feature_names_out()
for i, topic in enumerate(lsa_model.components_):
    top_terms = [terms[j] for j in topic.argsort()[-5:]]
    print(f"Topik {i+1}: {', '.join(top_terms)}")
# Out:
# Topik 1: presiden, cawapres, ganjar, prabowo, gibran
# Topik 2: anwar, mkmk, hakim, putusan, mk
# Topik 3: metro jaya, metro, tersangka, firli, kpk
# Topik 4: cak imin, imin, anies, kpu, debat
# Topik 5: prabowo, kpu, cawapres, gibran, debat
# Topik 6: prabowo, anies, cak, cak imin, imin
# Topik 7: debat, elektabilitas, gibran, persen, survei
# Topik 8: israel, pemilu, tni, survei, persen
# Topik 9: undang, capres cawapres, pemilu, partai, kpu
# Topik 10: panglima tni, panglima, jokowi, agus, tni

# %% [markdown]
# #### Visualasi

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from wordcloud import WordCloud

# %%
# Membuat model LSA dengan 10 topik
lsa_model = TruncatedSVD(n_components=10)
lsa_topic_matrix = lsa_model.fit_transform(X)

# Mendapatkan kata-kata teratas untuk setiap topik
terms = vectorizer.get_feature_names_out()
top_terms_per_topic = []
for topic in lsa_model.components_:
    top_terms = [terms[j] for j in topic.argsort()[-5:]]
    top_terms_per_topic.append(top_terms)

# Word Cloud
plt.figure(figsize=(14, 8))
for i in range(10):
    plt.subplot(2, 5, i+1)
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(top_terms_per_topic[i]))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(f'Topik {i+1}')
    plt.axis('off')
plt.suptitle('Word Cloud untuk Setiap Topik', fontsize=16)
plt.show()

# %%
# Bar Plot Topik Kata untuk LSA
plt.figure(figsize=(12, 8))
for i in range(10):
    plt.subplot(2, 5, i+1)
    top_terms = [terms[j] for j in lsa_model.components_[i].argsort()[-5:]]
    top_weights = sorted(lsa_model.components_[i])[-5:]
    sns.barplot(x=top_terms, y=top_weights)
    plt.title(f'Topik {i+1}')
    plt.xlabel('Kata')
    plt.ylabel('Bobot')
    plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
