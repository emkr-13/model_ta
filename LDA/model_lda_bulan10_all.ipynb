# %% [markdown]
# ### Model LDA dan Topik bulan 10

# %%
import pandas as pd
import concurrent.futures
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
# Fungsi untuk menerapkan model LDA pada data yang telah diproses
def apply_lda(processed_texts):
    vectorizer = CountVectorizer()
    X = vectorizer.fit_transform(processed_texts)
    
    lda = LatentDirichletAllocation(n_components=5, random_state=42)
    lda.fit(X)
    
    return lda, vectorizer

# Fungsi untuk membuat word cloud
def create_wordcloud(lda_model, vectorizer):
    # Ambil 10 kata kunci dari setiap topik
    keywords_per_topic = 10
    topics_keywords = []
    for index, topic in enumerate(lda_model.components_):
        top_words_indices = topic.argsort()[-keywords_per_topic:]
        top_words = [vectorizer.get_feature_names_out()[i] for i in top_words_indices]
        topics_keywords.append(top_words)
    
    # Gabungkan kata kunci dari semua topik menjadi satu teks
    all_keywords = ' '.join([word for sublist in topics_keywords for word in sublist])
    
    # Buat word cloud
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_keywords)
    
    # Tampilkan word cloud
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

# %%
df = pd.read_csv("grouped_news_2023-10.csv")
print(len(df))
# Out:
# 17969

# %%
df.head(10)
# Out:
#                                           url_berita nama_berita  \
# 0  https://20.detik.com/detikupdate/20231001-2310...  Detik News
# 1  https://20.detik.com/detikupdate/20230831-2308...  Detik News
# 2  https://20.detik.com/demi-indonesia/20231027-2...  Detik News
# 3  https://20.detik.com/detikupdate/20231001-2310...  Detik News
# 4  https://20.detik.com/detikupdate/20231001-2310...  Detik News
# 5  https://20.detik.com/detikupdate/20231001-2310...  Detik News
# 6  https://20.detik.com/detikupdate/20231001-2310...  Detik News
# 7  https://20.detik.com/detikupdate/20231001-2310...  Detik News
# 8  https://20.detik.com/detikupdate/20231001-2310...  Detik News
# 9  https://20.detik.com/demi-indonesia/20231027-2...  Detik News
#
#   tanggal_berita                                     processed_text
# 0     2023-10-01  20detik rangkum jadi heboh tarik pek   ya  sim...
# 1     2023-10-09  remaja palestina umur 14 tembak mati polisi is...
# 2     2023-10-27  menteri bumn  erick thohir bicara bangsa indon...
# 3     2023-10-01  presiden joko widodo pimpin upacara ingat sakt...
# 4     2023-10-01  gempa kuat m 5 4 guncang sukabumi  jawa barat ...
# 5     2023-10-01  menko polhukam  mahfud md buka suara temu 12 s...
# 6     2023-10-01  tum pkb  muhaimin iskandar cak imin bicara dug...
# 7     2023-10-01  ketua dpp pdip  said abdullah  ganjar pranowo ...
# 8     2023-10-01  presiden joko widodo pimpin upacara ingat sakt...
# 9     2023-10-27  raih emas olimpiade tokyo  greysia polii bicar...

# %%
df.dropna(subset=['processed_text'], inplace=True)

# %%
with concurrent.futures.ThreadPoolExecutor() as executor:
    lda_future = executor.submit(apply_lda, df['processed_text'])
    lda_model, vectorizer = lda_future.result()

# %%
print("Topik dari model LDA:")
for index, topic in enumerate(lda_model.components_):
    print(f"Topik {index+1}:")
    top_words_indices = topic.argsort()[-10:]  # Ubah menjadi 10 kata kunci per topik
    top_words = [vectorizer.get_feature_names_out()[i] for i in top_words_indices]
    print(top_words)
# Out:
# Topik dari model LDA:
# Topik 1:
# ['menteri', 'firli', 'tan', 'korupsi', 'syl', '10', 'periksa', 'syahrul', 'duga', 'kpk']
# Topik 2:
# ['serang', '10', 'hukum', 'gaza', 'hakim', '2023', 'usia', 'putus', 'mk', 'israel']
# Topik 3:
# ['10', 'calon', 'ketua', 'jokowi', 'ganjar', 'cawapres', 'partai', 'gibran', 'presiden', 'prabowo']
# Topik 4:
# ['tingkat', 'bangun', 'menteri', 'kerja', '10', 'negara', 'perintah', 'masyarakat', '2023', 'indonesia']
# Topik 5:
# ['warga', 'rumah', 'baca', 'polisi', 'laku', 'jalan', '2023', 'korban', '10', 'jakarta']

# %%
create_wordcloud(lda_model, vectorizer)
