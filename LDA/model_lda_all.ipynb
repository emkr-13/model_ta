# %% [markdown]
# ### Model LDA All

# %%
import pandas as pd
import concurrent.futures
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
# Fungsi untuk menerapkan model LDA pada data yang telah diproses
def apply_lda(processed_texts):
    vectorizer = CountVectorizer()
    X = vectorizer.fit_transform(processed_texts)
    
    lda = LatentDirichletAllocation(n_components=5, random_state=42)
    lda.fit(X)
    
    return lda, vectorizer

# Fungsi untuk membuat word cloud
def create_wordcloud(lda_model, vectorizer):
    # Ambil 10 kata kunci dari setiap topik
    keywords_per_topic = 10
    topics_keywords = []
    for index, topic in enumerate(lda_model.components_):
        top_words_indices = topic.argsort()[-keywords_per_topic:]
        top_words = [vectorizer.get_feature_names_out()[i] for i in top_words_indices]
        topics_keywords.append(top_words)
    
    # Gabungkan kata kunci dari semua topik menjadi satu teks
    all_keywords = ' '.join([word for sublist in topics_keywords for word in sublist])
    
    # Buat word cloud
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_keywords)
    
    # Tampilkan word cloud
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

# %%
df = pd.read_csv("pre_content_all.csv")
print(len(df))
# Out:
# 51896

# %%
df.head(10)
# Out:
#                                           url_berita nama_berita  \
# 0  https://20.detik.com/detikupdate/20231001-2310...  Detik News
# 1  https://20.detik.com/detikjabar/20231218-23121...  Detik News
# 2  https://20.detik.com/detikupdate/20230831-2308...  Detik News
# 3  https://20.detik.com/demi-indonesia/20231027-2...  Detik News
# 4  https://20.detik.com/detikupdate/20231001-2310...  Detik News
# 5  https://20.detik.com/detikupdate/20231001-2310...  Detik News
# 6  https://20.detik.com/detikupdate/20231001-2310...  Detik News
# 7  https://20.detik.com/detikupdate/20231001-2310...  Detik News
# 8  https://20.detik.com/detikupdate/20231001-2310...  Detik News
# 9  https://20.detik.com/detikupdate/20231001-2310...  Detik News
#
#   tanggal_berita                                     processed_text
# 0     01-10-2023  20detik rangkum jadi heboh tarik pek   ya  sim...
# 1     18-12-2023  iring mobil suv pasu awal presiden as joe bide...
# 2     09-10-2023  remaja palestina umur 14 tembak mati polisi is...
# 3     27-10-2023  menteri bumn  erick thohir bicara bangsa indon...
# 4     01-10-2023  presiden joko widodo pimpin upacara ingat sakt...
# 5     01-10-2023  gempa kuat m 5 4 guncang sukabumi  jawa barat ...
# 6     01-10-2023  menko polhukam  mahfud md buka suara temu 12 s...
# 7     01-10-2023  tum pkb  muhaimin iskandar cak imin bicara dug...
# 8     01-10-2023  ketua dpp pdip  said abdullah  ganjar pranowo ...
# 9     01-10-2023  presiden joko widodo pimpin upacara ingat sakt...

# %%
df.dropna(subset=['processed_text'], inplace=True)

# %%
with concurrent.futures.ThreadPoolExecutor() as executor:
    lda_future = executor.submit(apply_lda, df['processed_text'])
    lda_model, vectorizer = lda_future.result()

# %%
print("Topik dari model LDA:")
for index, topic in enumerate(lda_model.components_):
    print(f"Topik {index+1}:")
    top_words_indices = topic.argsort()[-10:]  # Ubah menjadi 10 kata kunci per topik
    top_words = [vectorizer.get_feature_names_out()[i] for i in top_words_indices]
    print(top_words)
# Out:
# Topik dari model LDA:
# Topik 1:
# ['rp', 'indonesia', 'bangun', 'kerja', 'kota', 'perintah', 'dki', 'masyarakat', '2023', 'jakarta']
# Topik 2:
# ['baca', 'orang', 'anak', 'rumah', 'laku', 'polisi', '2023', 'jalan', 'jakarta', 'korban']
# Topik 3:
# ['indonesia', 'mahfud', 'anies', 'jokowi', 'cawapres', 'partai', 'ganjar', 'presiden', 'gibran', 'prabowo']
# Topik 4:
# ['orang', 'hamas', '2023', 'serang', 'negara', 'palestina', 'indonesia', 'gaza', 'tni', 'israel']
# Topik 5:
# ['kait', 'korupsi', 'periksa', 'mk', '2023', 'putus', 'duga', 'firli', 'hukum', 'kpk']

# %%
create_wordcloud(lda_model, vectorizer)
