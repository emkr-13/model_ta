# %%
import pandas as pd
from concurrent.futures import ThreadPoolExecutor

def filter_data(chunk):
    # Membuat filter kata-kata yang diinginkan
    keywords = ['pemilu', 'mk', 'jokowi', 'kpu', 'ganjar', 'prabowo', 'anies', 'cak imin', 'gibran', 'mahfud md', 'capres', 'cawpres']
    
    # Membuang baris dengan nilai yang hilang (NaN) dalam kolom 'processed_text'
    chunk = chunk.dropna(subset=['processed_text'])
    
    # Membuat filter dengan menggunakan fungsi .contains()
    return chunk[chunk['processed_text'].str.contains('|'.join(keywords), case=False)]

# Membaca file CSV
df = pd.read_csv('pre_content_all.csv')

# Menentukan jumlah thread yang akan digunakan
num_threads = 4

# Membagi data menjadi beberapa chunk untuk diproses oleh thread yang berbeda
chunk_size = len(df) // num_threads

# Inisialisasi ThreadPoolExecutor
with ThreadPoolExecutor(max_workers=num_threads) as executor:
    # Memproses setiap chunk data secara paralel
    results = list(executor.map(filter_data, [df.iloc[i:i+chunk_size] for i in range(0, len(df), chunk_size)]))

# Menggabungkan hasil pemrosesan dari setiap thread
filtered_df = pd.concat(results)

# Menyimpan hasil filter ke dalam file CSV baru
filtered_df.to_csv('filtered_content.csv', index=False)

# Menampilkan hasil filter
filtered_df
# Out:
#                                               url_berita nama_berita  \
# 6      https://20.detik.com/detikupdate/20231001-2310...  Detik News
# 7      https://20.detik.com/detikupdate/20231001-2310...  Detik News
# 8      https://20.detik.com/detikupdate/20231001-2310...  Detik News
# 9      https://20.detik.com/detikupdate/20231001-2310...  Detik News
# 11     https://20.detik.com/detikupdate/20231001-2310...  Detik News
# ...                                                  ...         ...
# 51891  https://www.cnnindonesia.com/nasional/20231231...    CNN News
# 51892  https://www.cnnindonesia.com/nasional/20231231...    CNN News
# 51893  https://www.cnnindonesia.com/nasional/20231230...    CNN News
# 51894  https://www.cnnindonesia.com/nasional/20231231...    CNN News
# 51895  https://www.cnnindonesia.com/nasional/20231210...    CNN News
#
#       tanggal_berita                                     processed_text
# 6         01-10-2023  menko polhukam  mahfud md buka suara temu 12 s...
# 7         01-10-2023  tum pkb  muhaimin iskandar cak imin bicara dug...
# 8         01-10-2023  ketua dpp pdip  said abdullah  ganjar pranowo ...
# 9         01-10-2023  presiden joko widodo pimpin upacara ingat sakt...
# 11        01-10-2023  kpk ungkap oknum hilang barang bukti duga kait...
# ...              ...                                                ...
# 51891     31-12-2023  calon presiden nomor urut 3  ganjar pranowo ak...
# 51892     31-12-2023  gempa bumi kuat magnitudo 4 8 guncang wilayah ...
# 51893     30-12-2023  kembali uang proyek lampu pocong  nyata proyek...
# 51894     31-12-2023  calon presiden nomor urut 3  ganjar pranowo ja...
# 51895     11-12-2023  eks gubernur jawa timur gabung tim kampanye da...
#
# [28066 rows x 4 columns]
