# %%
import pandas as pd
from concurrent.futures import ThreadPoolExecutor

def filter_data(chunk):
    # Membuat filter kata-kata yang diinginkan
    keywords = ['pemilu', 'mk', 'jokowi', 'kpu', 'ganjar', 'prabowo', 'anies', 'cak imin', 'gibran', 'mahfud md', 'capres', 'cawpres']
    
    # Membuang baris dengan nilai yang hilang (NaN) dalam kolom 'processed_text'
    chunk = chunk.dropna(subset=['processed_text'])
    
    # Membuat filter dengan menggunakan fungsi .contains()
    return chunk[chunk['processed_text'].str.contains('|'.join(keywords), case=False)]

# Membaca file CSV
df = pd.read_csv('pre_content_1.csv')

# Menentukan jumlah thread yang akan digunakan
num_threads = 4

# Membagi data menjadi beberapa chunk untuk diproses oleh thread yang berbeda
chunk_size = len(df) // num_threads

# Inisialisasi ThreadPoolExecutor
with ThreadPoolExecutor(max_workers=num_threads) as executor:
    # Memproses setiap chunk data secara paralel
    results = list(executor.map(filter_data, [df.iloc[i:i+chunk_size] for i in range(0, len(df), chunk_size)]))

# Menggabungkan hasil pemrosesan dari setiap thread
filtered_df = pd.concat(results)

# Menyimpan hasil filter ke dalam file CSV baru
filtered_df.to_csv('filtered_content_1.csv', index=False)

# Menampilkan hasil filter
filtered_df
# Out:
#                                               url_berita  nama_berita  \
# 0      https://www.cnnindonesia.com/nasional/20231201...     CNN News
# 1      https://news.detik.com/kolom/d-6958996/jokowi-...   Detik News
# 2      https://nasional.kompas.com/read/2023/11/06/13...  Kompas News
# 4      https://megapolitan.kompas.com/read/2023/11/25...  Kompas News
# 5      https://www.cnnindonesia.com/nasional/20231007...     CNN News
# ...                                                  ...          ...
# 51364  https://news.detik.com/pemilu/d-7056937/yenny-...   Detik News
# 51365  https://news.detik.com/pemilu/d-7007439/dukung...   Detik News
# 51366  https://www.cnnindonesia.com/nasional/20231125...     CNN News
# 51371  https://news.detik.com/pemilu/d-7071407/zita-a...   Detik News
# 51375  https://20.detik.com/detikupdate/20231219-2312...   Detik News
#
#       tanggal_berita                                     processed_text
# 0         01-12-2023  1 desemb 2023 komisi penanggulangan aid kpa ka...
# 1         01-10-2023  1 oktob 2023 rapat nasion rakerna pdi perjuang...
# 2         06-11-2023  10 calon anggota legislatif caleg berusia 80 t...
# 4         25-11-2023  10 guru sekolah dasar negeri sdn cimun 1 kecam...
# 5         07-10-2023  10 hektar lahan kabupaten ogan komer ulu oku s...
# ...              ...                                                ...
# 51364     26-11-2023  zannuba ariffah chafsoh yenni wahid putri mant...
# 51365     29-10-2023  zannuba ariffah chafsoh yenni wahid putri pres...
# 51366     25-11-2023  zannuba ariffah chafsoh yenni wahid putri pres...
# 51371     04-12-2023  zita anjani bagibagi susu grati car free day j...
# 51375     19-12-2023  zulha mengklaim presiden jokowi partainya pan ...
#
# [30997 rows x 4 columns]
