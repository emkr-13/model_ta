# %%
import pandas as pd
from concurrent.futures import ThreadPoolExecutor

def filter_data(chunk):
    # Membuat filter kata-kata yang diinginkan
    keywords = ['pemilu', 'mk', 'jokowi', 'kpu', 'ganjar', 'prabowo', 'anies', 'cak imin', 'gibran', 'mahfud md', 'capres', 'cawpres']
    
    # Membuang baris dengan nilai yang hilang (NaN) dalam kolom 'processed_text'
    chunk = chunk.dropna(subset=['processed_text'])
    
    # Membuat filter dengan menggunakan fungsi .contains()
    return chunk[chunk['processed_text'].str.contains('|'.join(keywords), case=False)]

# Membaca file CSV
df = pd.read_csv('pre_content_cek.csv')

# Menentukan jumlah thread yang akan digunakan
num_threads = 4

# Membagi data menjadi beberapa chunk untuk diproses oleh thread yang berbeda
chunk_size = len(df) // num_threads

# Inisialisasi ThreadPoolExecutor
with ThreadPoolExecutor(max_workers=num_threads) as executor:
    # Memproses setiap chunk data secara paralel
    results = list(executor.map(filter_data, [df.iloc[i:i+chunk_size] for i in range(0, len(df), chunk_size)]))

# Menggabungkan hasil pemrosesan dari setiap thread
filtered_df = pd.concat(results)

# Menyimpan hasil filter ke dalam file CSV baru
filtered_df.to_csv('filtered_content_cek.csv', index=False)

# Menampilkan hasil filter
filtered_df
# Out:
#                                               url_berita nama_berita  \
# 0      https://20.detik.com/advertorial/20231109-2311...  Detik News
# 5      https://20.detik.com/demi-indonesia/20231027-2...  Detik News
# 6      https://20.detik.com/detikupdate/20231001-2310...  Detik News
# 7      https://20.detik.com/detikupdate/20231001-2310...  Detik News
# 8      https://20.detik.com/detikupdate/20231001-2310...  Detik News
# ...                                                  ...         ...
# 51873  https://www.cnnindonesia.com/nasional/20231229...    CNN News
# 51874  https://www.cnnindonesia.com/nasional/20231231...    CNN News
# 51875  https://www.cnnindonesia.com/nasional/20231230...    CNN News
# 51876  https://www.cnnindonesia.com/nasional/20231230...    CNN News
# 51878  https://www.cnnindonesia.com/nasional/20231230...    CNN News
#
#       tanggal_berita                                     processed_text
# 0         10-11-2023  maha barudak wellyuk ramai pesta anak nongkron...
# 5         27-10-2023  kapolri jenderal lisyto sigit prabowo bicara s...
# 6         01-10-2023  menko polhukam mahfud md buka suara temu 12 se...
# 7         01-10-2023  tum pkb muhaimin iskandar cak imin bicara duga...
# 8         01-10-2023  sekjen pdip hasto kristiyanto benar ganjar pra...
# ...              ...                                                ...
# 51873     29-12-2023  polda bal rekayasa lintas tutup jalan malam ta...
# 51874     31-12-2023  calon presiden nomor urut 3 ganjar pranowo kom...
# 51875     30-12-2023  calon presiden nomor urut 3 ganjar pranowo des...
# 51876     30-12-2023  presiden joko widodo jokowi mewantiwanti komis...
# 51878     30-12-2023  calon presiden nomor urut 3 ganjar pranowo nil...
#
# [28990 rows x 4 columns]
