# %% [markdown]
# ### Model LDA All

# %%
import pandas as pd
import concurrent.futures
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
# Fungsi untuk menerapkan model LDA pada data yang telah diproses
def apply_lda(processed_texts):
    vectorizer = CountVectorizer()
    X = vectorizer.fit_transform(processed_texts)
    
    lda = LatentDirichletAllocation(n_components=5, random_state=42)
    lda.fit(X)
    
    return lda, vectorizer

# Fungsi untuk membuat word cloud
def create_wordcloud(lda_model, vectorizer):
    # Ambil 10 kata kunci dari setiap topik
    keywords_per_topic = 10
    topics_keywords = []
    for index, topic in enumerate(lda_model.components_):
        top_words_indices = topic.argsort()[-keywords_per_topic:]
        top_words = [vectorizer.get_feature_names_out()[i] for i in top_words_indices]
        topics_keywords.append(top_words)
    
    # Gabungkan kata kunci dari semua topik menjadi satu teks
    all_keywords = ' '.join([word for sublist in topics_keywords for word in sublist])
    
    # Buat word cloud
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_keywords)
    
    # Tampilkan word cloud
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

# %%
df = pd.read_csv("filtered_content.csv")
print(len(df))
# Out:
# 28066

# %%
df.head(10)
# Out:
#                                           url_berita nama_berita  \
# 0  https://20.detik.com/detikupdate/20231001-2310...  Detik News
# 1  https://20.detik.com/detikupdate/20231001-2310...  Detik News
# 2  https://20.detik.com/detikupdate/20231001-2310...  Detik News
# 3  https://20.detik.com/detikupdate/20231001-2310...  Detik News
# 4  https://20.detik.com/detikupdate/20231001-2310...  Detik News
# 5  https://20.detik.com/detikupdate/20231001-2310...  Detik News
# 6  https://20.detik.com/detikupdate/20231001-2310...  Detik News
# 7  https://20.detik.com/detikupdate/20231001-2310...  Detik News
# 8  https://20.detik.com/detikupdate/20231001-2310...  Detik News
# 9  https://20.detik.com/detikupdate/20231001-2310...  Detik News
#
#   tanggal_berita                                     processed_text
# 0     01-10-2023  menko polhukam  mahfud md buka suara temu 12 s...
# 1     01-10-2023  tum pkb  muhaimin iskandar cak imin bicara dug...
# 2     01-10-2023  ketua dpp pdip  said abdullah  ganjar pranowo ...
# 3     01-10-2023  presiden joko widodo pimpin upacara ingat sakt...
# 4     01-10-2023  kpk ungkap oknum hilang barang bukti duga kait...
# 5     01-10-2023  sekjen pdip  hasto kristiyanto benar ganjar pr...
# 6     01-10-2023  kepala desa  kades  kabupaten bandung  banjara...
# 7     01-10-2023  tum pkb muhaimin iskandar cak imin respons pid...
# 8     01-10-2023  menko polhukam  mahfud md  buka suara oknum co...
# 9     01-10-2023  ketua pdip  megawati soekarnoputri kader satu ...

# %%
df.dropna(subset=['processed_text'], inplace=True)

# %%
with concurrent.futures.ThreadPoolExecutor() as executor:
    lda_future = executor.submit(apply_lda, df['processed_text'])
    lda_model, vectorizer = lda_future.result()

# %%
print("Topik dari model LDA:")
for index, topic in enumerate(lda_model.components_):
    print(f"Topik {index+1}:")
    top_words_indices = topic.argsort()[-10:]  # Ubah menjadi 10 kata kunci per topik
    top_words = [vectorizer.get_feature_names_out()[i] for i in top_words_indices]
    print(top_words)
# Out:
# Topik dari model LDA:
# Topik 1:
# ['nomor', 'cawapres', 'pilih', 'milu', 'usia', '2023', 'hakim', 'konstitusi', 'putus', 'mk']
# Topik 2:
# ['calon', 'indonesia', 'capres', 'debat', 'jokowi', 'cawapres', 'partai', 'presiden', 'gibran', 'prabowo']
# Topik 3:
# ['milu', 'jokowi', 'kota', 'jakarta', 'negara', 'bangun', 'perintah', '2023', 'masyarakat', 'indonesia']
# Topik 4:
# ['10', 'baca', 'rp', 'hasil', 'jalan', 'rumah', 'survei', '2023', 'jakarta', 'persen']
# Topik 5:
# ['hukum', 'ketua', 'jokowi', 'jakarta', '2023', 'kpk', 'anies', 'presiden', 'mahfud', 'ganjar']

# %%
create_wordcloud(lda_model, vectorizer)
